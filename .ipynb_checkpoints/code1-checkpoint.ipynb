# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, roc_auc_score
from tqdm import tqdm
from tqdm import tqdm_notebook
import warnings
import gc
import os
import time
import sys
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
from sklearn import metrics

plt.style.use('seaborn')
sns.set(font_scale=1)
pd.set_option('display.max_columns', 500)

# %%
path = 'input'
Metro_roadMap = pd.read_csv(path + '/Metro_roadMap.csv')
Metro_roadMap.rename(columns={'Unnamed: 0':'stationID'},inplace=True)
testB_record  = pd.read_csv(path + '/Metro_testA/testA_record_2019-01-28.csv')
testB_submit  = pd.read_csv(path + '/Metro_testA/testA_submit_2019-01-29.csv')

# %%
#获取测试集日期
testB_submit['time']    = pd.to_datetime(testB_submit['startTime'])
test_day                = int(testB_submit['time'].dt.day.mean())
test_week               = int(testB_submit['time'].dt.dayofweek.mean())
del testB_submit['time']

# %%
# 时间转化
def trans_time_10_minutes(x):
    x_split = x.split(':')
    x_part1 = x_split[0]
    x_part2 = int(x_split[1]) // 10
    if x_part2 == 0:
        x_part2 = '00'
    else:
        x_part2 = str(x_part2 * 10)
    return x_part1 + ':' + x_part2 + ':00'

def get_base_features(df_):
    
    df = df_.copy()
    
    # base time
    df['time']    = pd.to_datetime(df['time'])
    df['day' ]    = df['time'].dt.day  
    df['week']    = df['time'].dt.dayofweek 
    df['hour']    = df['time'].dt.hour 
    df['minute']  = df['time'].dt.minute 
    df['ten_minutes_in_day'] = df['hour'] * 6 + df['time'].dt.minute // 10 
    
    df['time_ten_minutes'] = df['time'].astype(str).apply(lambda x: trans_time_10_minutes(x))
    
    # count,sum
    result = df.groupby(['stationID', 'time_ten_minutes', 'week', 'day', 'hour', 'ten_minutes_in_day'\
                        ]).status.agg(['count', 'sum']).reset_index()
    
    # in,out
    result['inNums']  = result['sum']
    result['outNums'] = result['count'] - result['sum']
    
    result.fillna(0, inplace=True)
    del result['sum'],result['count']
    
    return result
data = get_base_features(testB_record)
data = data[:0]

# %%
data_list = os.listdir(path+'/Metro_train/')
for i in range(0, len(data_list)):
    if data_list[i].split('.')[-1] == 'csv':
        print(data_list[i], i)
        df = pd.read_csv(path+'/Metro_train/' + data_list[i])
        df = get_base_features(df)
        data = pd.concat([data, df], axis=0, ignore_index=True)
    else:
        continue
data = pd.concat([data, get_base_features(testB_record)], axis=0, ignore_index=True)
data.to_csv(path+'/data.csv', index=False)
data = pd.read_csv(path+'/data.csv')
# Out:
# record_2019-01-01.csv 0
# record_2019-01-02.csv 1
# record_2019-01-03.csv 2
# record_2019-01-04.csv 3
# record_2019-01-05.csv 4
# record_2019-01-06.csv 5
# record_2019-01-07.csv 6
# record_2019-01-08.csv 7
# record_2019-01-09.csv 8
# record_2019-01-10.csv 9
# record_2019-01-11.csv 10
# record_2019-01-12.csv 11
# record_2019-01-13.csv 12
# record_2019-01-14.csv 13
# record_2019-01-15.csv 14
# record_2019-01-16.csv 15
# record_2019-01-17.csv 16
# record_2019-01-18.csv 17
# record_2019-01-19.csv 18
# record_2019-01-20.csv 19
# record_2019-01-21.csv 20
# record_2019-01-22.csv 21
# record_2019-01-23.csv 22
# record_2019-01-24.csv 23
# record_2019-01-25.csv 24

# %%
#剔除与测试集分布差异大的日期
if (test_week!=6)&(test_week!=5):
    # 方案三移除周一周二周六周日
    df_data_noAbnormal = data.loc[((data.week != 6) & (data.week != 5) & (data.week != 1) & (data.week != 0))].copy()

df_data_noAbnormal.rename(columns={'time_ten_minutes':'startTime'}, inplace=True)

# 保留日期
retain_days = list(df_data_noAbnormal.day.unique())
print(retain_days)
# Out:
# [2, 3, 4, 9, 10, 11, 16, 17, 18, 23, 24, 25]

# %%
### 保留日+测试集日期
days = retain_days + [test_day]

days_relative = {}  # 重新计算rank,方便我们后续提取特征
for i,d in enumerate(days):
    days_relative[d] = i + 1
print(days_relative)
# Out:
# {2: 1, 3: 2, 4: 3, 9: 4, 10: 5, 11: 6, 16: 7, 17: 8, 18: 9, 23: 10, 24: 11}

# %%
stationIDs = testB_submit['stationID'].unique()
times = [] 
for day in days: 
    if day < 10:
        day_str = '0' + str(day)
    else:
        day_str = str(day)
        
    for hour in range(24):
        if hour < 10:
            hour_str = '0' + str(hour)
        else:
            hour_str = str(hour)

        for minutes in range(6):
            if minutes == 0:
                minutes_str = '0' + str(minutes)
            else:
                minutes_str = str(minutes * 10) 
            times.append('2019-01-' + day_str + ' ' + hour_str +':' + minutes_str + ':00')
from itertools import product
stationids_by_times = list(product(stationIDs, times))
df_data = pd.DataFrame()
df_data['stationID'] = np.array(stationids_by_times)[:,0]
df_data['startTime'] = np.array(stationids_by_times)[:,1]
df_data = df_data.sort_values(['stationID','startTime'])
df_data['endTime'] = df_data.groupby('stationID')['startTime'].shift(-1).values

# %%
def filltime(x):
    x_split = x.split(' ')[0].split('-')
    x_part1_1 = x_split[0] +'-'+x_split[1]+'-'
    x_part1_2 = int(x_split[2]) + 1
    if x_part1_2 < 10:
        x_part1_2 = '0' + str(x_part1_2)
    else:
        x_part1_2 = str(x_part1_2)
        
    x_part2 = ' 00:00:00'
    return x_part1_1 + x_part1_2 + x_part2

df_data.loc[df_data.endTime.isnull(), 'endTime']  = df_data.loc[df_data.endTime.isnull(), 'startTime'].apply(lambda x: filltime(x)) 
df_data['stationID'] = df_data['stationID'].astype(int)

# %%
# 非特殊日期流量
df_data = df_data.merge(df_data_noAbnormal, on=['stationID', 'startTime'], how='left')
df_data['inNums']  = df_data['inNums'].fillna(0)
df_data['outNums'] = df_data['outNums'].fillna(0)

# 构造base time        
df_data['time']                 = pd.to_datetime(df_data['startTime'])
df_data['day' ]                 = df_data['time'].dt.day  
df_data['days_relative']        = df_data['day'].map(days_relative)
df_data['hour']                 = df_data['time'].dt.hour 
df_data['minute']               = df_data['time'].dt.minute 
df_data['week']                 = df_data['time'].dt.dayofweek 
df_data['ten_minutes_in_day']   = df_data['hour'] * 6 + df_data['time'].dt.minute // 10 
del df_data['time']

# %%
def get_stationID_fea(df):
    df_station               = pd.DataFrame()
    df_station['stationID']  = df['stationID'].unique()
    df_station               = df_station.sort_values('stationID')
    
    tmp1  = df.groupby(['stationID'])['deviceID'].nunique().to_frame('stationID_deviceID_nunique').reset_index()
    tmp2  = df.groupby(['stationID'])['userID'].nunique().to_frame('stationID_userID_nunique').reset_index()
    
    df_station = df_station.merge(tmp1,on ='stationID', how='left')
    df_station = df_station.merge(tmp2,on ='stationID', how='left')
    
    for pivot_cols in tqdm_notebook(['payType','hour','days_relative','ten_minutes_in_day']): 
        
        tmp = df.groupby(['stationID',pivot_cols])['deviceID'].count().to_frame('stationID_'+pivot_cols+'_cnt').reset_index()
        df_tmp = tmp.pivot(index = 'stationID', columns=pivot_cols, values='stationID_'+pivot_cols+'_cnt')
        cols   = ['stationID_'+pivot_cols+'_cnt' + str(col) for col in df_tmp.columns]
        df_tmp.columns = cols
        df_tmp.reset_index(inplace = True)
        df_station = df_station.merge(df_tmp, on ='stationID', how='left')
    return df_station

# %%
df_station = get_base_features(testB_record)
df_station = df_station[:0]
data_list = os.listdir(path+'/Metro_train/')
# 提取最近n天符合分布的日期构造station相关特征
if (test_week!=6)&(test_week!=5):
    #station_day = [23,24,25] # 线上
    station_day = [16,17,18] # 方案三
for dtname in data_list:
    d = int(dtname[15:17])
    if (d in station_day) & (dtname.split('.')[-1] == 'csv'):
        print(dtname, d)
        df = pd.read_csv(path+'/Metro_train/' + dtname)
        df_station = pd.concat([df_station, df], axis=0, ignore_index=True)
    else:
        continue

df_station['time']               = pd.to_datetime(df_station['time'])
df_station['day']                = df_station['time'].dt.day  
df_station['week']               = df_station['time'].dt.dayofweek 
df_station['hour']               = df_station['time'].dt.hour 
df_station['ten_minutes_in_day'] = df_station['hour'] * 6 + df_station['time'].dt.minute // 10 
df_station['time_ten_minutes']   = df_station['time'].astype(str).apply(lambda x: trans_time_10_minutes(x))
df_station['days_relative']      = df_station['day'].map(days_relative)
df_station = get_stationID_fea(df_station)

def get_stationID_fea(df):
    df_station               = pd.DataFrame()
    df_station['stationID']  = df['stationID'].unique()
    cols = [str(i) for i in range(81)]  
    df_station['num_of_join_points'] = df[cols].sum(axis=1).sort_values()
    return df_station
df_station_metro = get_stationID_fea(Metro_roadMap)
# Out:
# record_2019-01-16.csv 16
# record_2019-01-17.csv 17
# record_2019-01-18.csv 18
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))

# %%
def time_before_trans(x,dic_):
    if x in dic_.keys():
        return dic_[x]
    else:
        return np.nan
def generate_fea_y(df, day, n):
    df_feature_y   =  df.loc[df.days_relative == day].copy() 
    
    df_feature_y['tmp_10_minutes'] = df_feature_y['stationID'].values * 1000 + df_feature_y['ten_minutes_in_day'].values
    df_feature_y['tmp_hours']      = df_feature_y['stationID'].values * 1000 + df_feature_y['hour'].values
    
    for i in range(n): # 前n天每一天
        d = day - i - 1
        df_d = df.loc[df.days_relative == d].copy() # 当天的数据
        
        # 特征1：过去在该时间段（一样的时间段,10minutes）有多少出入量
        df_d['tmp_10_minutes'] = df['stationID'] * 1000 + df['ten_minutes_in_day']  
        df_d['tmp_hours']      = df['stationID'] * 1000 + df['hour']
        # sum
        dic_innums  = df_d.groupby(['tmp_10_minutes'])['inNums'].sum().to_dict()
        dic_outnums = df_d.groupby(['tmp_10_minutes'])['outNums'].sum().to_dict()
        df_feature_y['_bf_' + str(day -d) + '_innum_10minutes']  =  df_feature_y['tmp_10_minutes'].map(dic_innums).values
        df_feature_y['_bf_' + str(day -d) + '_outnum_10minutes'] =  df_feature_y['tmp_10_minutes'].map(dic_outnums).values
        
        # 特征2：过去在该时间段（小时）有多少出入量
        dic_innums  = df_d.groupby(['tmp_hours'])['inNums'].sum().to_dict()
        dic_outnums = df_d.groupby(['tmp_hours'])['outNums'].sum().to_dict()   
        df_feature_y['_bf_' + str(day -d) + '_innum_hour']  =  df_feature_y['tmp_hours'].map(dic_innums).values
        df_feature_y['_bf_' + str(day -d) + '_outnum_hour'] =  df_feature_y['tmp_hours'].map(dic_outnums).values   
        
        # 特征3: 上10分钟
        df_d['tmp_10_minutes_bf'] = df['stationID'] * 1000 + df['ten_minutes_in_day'] - 1
        df_d['tmp_hours_bf']      = df['stationID'] * 1000 + df['hour'] - 1
        # sum
        dic_innums  = df_d.groupby(['tmp_10_minutes_bf'])['inNums'].sum().to_dict()
        dic_outnums = df_d.groupby(['tmp_hours_bf'])['outNums'].sum().to_dict()
        df_feature_y['_bf21_' + str(day -d) + '_innum_10minutes']  =  df_feature_y['tmp_10_minutes'].agg(lambda x: time_before_trans(x,dic_innums)).values
        df_feature_y['_bf1_' + str(day -d) + '_outnum_10minutes'] =  df_feature_y['tmp_10_minutes'].agg(lambda x: time_before_trans(x,dic_outnums)).values
        
        # 特征4： 上个小时情况
        dic_innums  = df_d.groupby(['tmp_hours_bf'])['inNums'].sum().to_dict()
        dic_outnums = df_d.groupby(['tmp_hours_bf'])['outNums'].sum().to_dict()   
        df_feature_y['_bf1_' + str(day -d) + '_innum_hour']  =  df_feature_y['tmp_hours'].map(dic_innums).values
        df_feature_y['_bf1_' + str(day -d) + '_outnum_hour'] =  df_feature_y['tmp_hours'].map(dic_outnums).values
        
    
    for col in ['tmp_10_minutes','tmp_hours']:
        del df_feature_y[col]
        
    return df_feature_y

# %%
df_feature_y = pd.DataFrame()
# 确定范围
if (test_week!=6)&(test_week!=5):
    #left = 6  # 线上
    left = 4   #线下  方案三，只提取前三天的信息
right = days_relative[test_day]+1
print(left,right)
# 前n天每一天，以days_relative为准
for day in range(left,right):
    if i == 0: 
        df_feature_y = generate_fea_y(df_data, day = day, n=left-1)
    else:
        df_feature_tmp = generate_fea_y(df_data, day = day, n=left-1)
        df_feature_y   = pd.concat([df_feature_y,df_feature_tmp], axis=0, ignore_index=True)
# Out:
# 4 12

# %%
columns = ['_innum_10minutes','_outnum_10minutes','_innum_hour','_outnum_hour']
# # 过去n天的sum,mean
for i in range(2,left):
    for f in columns:
        colname1 = '_bf_'+str(i)+'_'+'days'+f+'_sum'
        df_feature_y[colname1] = 0
        for d in range(1,i+1):
            df_feature_y[colname1] = df_feature_y[colname1] + df_feature_y['_bf_'+str(d) +f]
        colname2 = '_bf_'+str(d)+'_'+'days'+f+'_mean'
        df_feature_y[colname2] = df_feature_y[colname1] / i
        
# 过去n天的mean的差分
for i in range(2,left): 
    for f in columns:
        colname1 = '_bf_'+str(d)+'_'+'days'+f+'_mean'
        colname2 = '_bf_'+str(d)+'_'+'days'+f+'_mean_diff'
        df_feature_y[colname2] = df_feature_y[colname1].diff(1)
        df_feature_y.loc[(df_feature_y.hour==0)&(df_feature_y.minute==0), colname2] = 0

# %%
data = df_feature_y.copy()
data = data.merge(df_station, on ='stationID', how='left')
data = data.merge(df_station_metro, on ='stationID', how='left')

# %%
if (test_week!=6)&(test_week!=5):
    print('线下平滑到17号的趋势, 线上平滑到24号趋势')
    # 构造小时流量
    inNums_hour  = data[data.day!=24].groupby(['stationID','week','day','hour'])['inNums' ].sum().reset_index(name='inNums_hour_sum')
    outNums_hour = data[data.day!=24].groupby(['stationID','week','day','hour'])['outNums'].sum().reset_index(name='outNums_hour_sum')
    # 合并新构造特征
    data = data.merge(inNums_hour , on=['stationID','week','day','hour'], how='left')
    data = data.merge(outNums_hour, on=['stationID','week','day','hour'], how='left')
    data.fillna(0, inplace=True)
    # 提取17号流量
    test_nums  = data.loc[data.day==17, ['stationID','ten_minutes_in_day','inNums_hour_sum','outNums_hour_sum']]
    test_nums.columns  = ['stationID','ten_minutes_in_day','test_inNums_hour_sum' ,'test_outNums_hour_sum']
    # 合并17号流量
    data = data.merge(test_nums , on=['stationID','ten_minutes_in_day'], how='left')
    # 构造每天与的趋势
    data['test_inNums_hour_trend']  = (data['test_inNums_hour_sum'] + 1) / (data['inNums_hour_sum'] + 1 )
    data['test_outNums_hour_trend'] = (data['test_outNums_hour_sum'] + 1) / (data['outNums_hour_sum'] + 1)

    del data['inNums_hour_sum']
    del data['outNums_hour_sum']
    del data['test_inNums_hour_sum']
    del data['test_outNums_hour_sum']
# Out:
# 线下平滑到17号的趋势, 线上平滑到24号趋势

# %%
data.day.unique()
# Out:
# array([ 9, 10, 11, 16, 17, 18, 23, 24], dtype=int64)

# %%
if (test_week!=6)&(test_week!=5):
    print('线下平滑到17号的趋势, 线上平滑到24号趋势')
    data['inNums_online']  = data['inNums']
    data['outNums_online'] = data['outNums']
    for sid in range(0,81):
        print('inNums stationID:', sid)
        for d in range(2,17):
            inNums = data.loc[(data.stationID==sid)&(data.day==d),'inNums']
            trend  = data.loc[(data.stationID==sid)&(data.day==d),'test_inNums_hour_trend']
            data.loc[(data.stationID==sid)&(data.day==d),'inNums_online'] = trend.values*(inNums.values+1)-1
        for d in range(18,19):
            inNums = data.loc[(data.stationID==sid)&(data.day==d),'inNums']
            trend  = data.loc[(data.stationID==sid)&(data.day==d),'test_inNums_hour_trend']
            data.loc[(data.stationID==sid)&(data.day==d),'inNums_online'] = trend.values*(inNums.values+1)-1

    for sid in range(0,81):
        print('outNums stationID:', sid)
        for d in range(2,17):
            outNums = data.loc[(data.stationID==sid)&(data.day==d),'outNums']
            trend   = data.loc[(data.stationID==sid)&(data.day==d),'test_outNums_hour_trend']
            data.loc[(data.stationID==sid)&(data.day==d),'outNums_online'] = trend.values*(outNums.values+1)-1
        for d in range(18,19):
            outNums = data.loc[(data.stationID==sid)&(data.day==d),'outNums']
            trend   = data.loc[(data.stationID==sid)&(data.day==d),'test_outNums_hour_trend']
            data.loc[(data.stationID==sid)&(data.day==d),'outNums_online'] = trend.values*(outNums.values+1)-1

    # 后处理
    data.loc[data.inNums_online <0 , 'inNums_online' ] = 0
    data.loc[data.outNums_online<0 , 'outNums_online'] = 0

    data['inNums']  = data['inNums_online']
    data['outNums'] = data['outNums_online']
    del data['inNums_online']
    del data['outNums_online']
    del data['test_inNums_hour_trend']
    del data['test_outNums_hour_trend']
# Out:
# 线下平滑到17号的趋势, 线上平滑到24号趋势
# inNums stationID: 0
# inNums stationID: 1
# inNums stationID: 2
# inNums stationID: 3
# inNums stationID: 4
# inNums stationID: 5
# inNums stationID: 6
# inNums stationID: 7
# inNums stationID: 8
# inNums stationID: 9
# inNums stationID: 10
# inNums stationID: 11
# inNums stationID: 12
# inNums stationID: 13
# inNums stationID: 14
# inNums stationID: 15
# inNums stationID: 16
# inNums stationID: 17
# inNums stationID: 18
# inNums stationID: 19
# inNums stationID: 20
# inNums stationID: 21
# inNums stationID: 22
# inNums stationID: 23
# inNums stationID: 24
# inNums stationID: 25
# inNums stationID: 26
# inNums stationID: 27
# inNums stationID: 28
# inNums stationID: 29
# inNums stationID: 30
# inNums stationID: 31
# inNums stationID: 32
# inNums stationID: 33
# inNums stationID: 34
# inNums stationID: 35
# inNums stationID: 36
# inNums stationID: 37
# inNums stationID: 38
# inNums stationID: 39
# inNums stationID: 40
# inNums stationID: 41
# inNums stationID: 42
# inNums stationID: 43
# inNums stationID: 44
# inNums stationID: 45
# inNums stationID: 46
# inNums stationID: 47
# inNums stationID: 48
# inNums stationID: 49
# inNums stationID: 50
# inNums stationID: 51
# inNums stationID: 52
# inNums stationID: 53
# inNums stationID: 54
# inNums stationID: 55
# inNums stationID: 56
# inNums stationID: 57
# inNums stationID: 58
# inNums stationID: 59
# inNums stationID: 60
# inNums stationID: 61
# inNums stationID: 62
# inNums stationID: 63
# inNums stationID: 64
# inNums stationID: 65
# inNums stationID: 66
# inNums stationID: 67
# inNums stationID: 68
# inNums stationID: 69
# inNums stationID: 70
# inNums stationID: 71
# inNums stationID: 72
# inNums stationID: 73
# inNums stationID: 74
# inNums stationID: 75
# inNums stationID: 76
# inNums stationID: 77
# inNums stationID: 78
# inNums stationID: 79
# inNums stationID: 80
# outNums stationID: 0
# outNums stationID: 1
# outNums stationID: 2
# outNums stationID: 3
# outNums stationID: 4
# outNums stationID: 5
# outNums stationID: 6
# outNums stationID: 7
# outNums stationID: 8
# outNums stationID: 9
# outNums stationID: 10
# outNums stationID: 11
# outNums stationID: 12
# outNums stationID: 13
# outNums stationID: 14
# outNums stationID: 15
# outNums stationID: 16
# outNums stationID: 17
# outNums stationID: 18
# outNums stationID: 19
# outNums stationID: 20
# outNums stationID: 21
# outNums stationID: 22
# outNums stationID: 23
# outNums stationID: 24
# outNums stationID: 25
# outNums stationID: 26
# outNums stationID: 27
# outNums stationID: 28
# outNums stationID: 29
# outNums stationID: 30
# outNums stationID: 31
# outNums stationID: 32
# outNums stationID: 33
# outNums stationID: 34
# outNums stationID: 35
# outNums stationID: 36
# outNums stationID: 37
# outNums stationID: 38
# outNums stationID: 39
# outNums stationID: 40
# outNums stationID: 41
# outNums stationID: 42
# outNums stationID: 43
# outNums stationID: 44
# outNums stationID: 45
# outNums stationID: 46
# outNums stationID: 47
# outNums stationID: 48
# outNums stationID: 49
# outNums stationID: 50
# outNums stationID: 51
# outNums stationID: 52
# outNums stationID: 53
# outNums stationID: 54
# outNums stationID: 55
# outNums stationID: 56
# outNums stationID: 57
# outNums stationID: 58
# outNums stationID: 59
# outNums stationID: 60
# outNums stationID: 61
# outNums stationID: 62
# outNums stationID: 63
# outNums stationID: 64
# outNums stationID: 65
# outNums stationID: 66
# outNums stationID: 67
# outNums stationID: 68
# outNums stationID: 69
# outNums stationID: 70
# outNums stationID: 71
# outNums stationID: 72
# outNums stationID: 73
# outNums stationID: 74
# outNums stationID: 75
# outNums stationID: 76
# outNums stationID: 77
# outNums stationID: 78
# outNums stationID: 79
# outNums stationID: 80

# %%
all_columns = [f for f in data.columns if f not in ['startTime','endTime','inNums','outNums']]

# %%
### all data
data.fillna(0, inplace=True)
all_data = data[data.day!=test_day]
X_data = all_data[all_columns].values

test  = data[data.day==test_day]
X_test = test[all_columns].values

# %%
def train_model(X, X_test, y, params, folds, model_type='lgb'):
    oof = np.zeros(X.shape[0])
    predictions = np.zeros(X_test.shape[0])
    scores = []
    for fold_n, (trn_idx, val_idx) in enumerate(folds.split(X, y)):
        print('Fold', fold_n, 'started at', time.ctime())
        
        if model_type == 'lgb':
            trn_data = lgb.Dataset(X[trn_idx], y[trn_idx])
            val_data = lgb.Dataset(X[val_idx], y[val_idx])
            clf = lgb.train(params,
                            trn_data,
                            num_boost_round=20000,
                            valid_sets=[trn_data,val_data],
                            valid_names=['train','valid'],
                            early_stopping_rounds=200,
                            verbose_eval=400,
                            )
            oof[val_idx] = clf.predict(X[val_idx], num_iteration=clf.best_iteration)
            predictions += clf.predict(X_test, num_iteration=clf.best_iteration) / folds.n_splits
       
        
        scores.append(mean_absolute_error(oof[val_idx], y[val_idx]))
        
        
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    return oof, predictions, scores

# %%
lgb_params = {'num_leaves': 63,
              'min_data_in_leaf': 25, 
              'objective':'regression_l1',
              'max_depth': -1,
              'learning_rate': 0.05,
              'min_child_samples': 20,
              'boosting': 'gbdt',
              'feature_fraction': 0.9,
              'bagging_fraction': 0.9 ,
              'bagging_seed': 11,
              'metric': 'mae',
              'lambda_l1': 0.1,
              'nthread': -1,
              'verbosity': -1}

# %%
folds = KFold(n_splits=10, shuffle=True, random_state=2019)
oof_in , predictions_in , scores_in  = train_model(X_data , X_test, all_data['inNums'], params=lgb_params, folds=folds, model_type='lgb')
test['pred_inNums']= predictions_in
# Out:
# Fold 0 started at Tue Apr  2 19:13:01 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2457	valid's l1: 10.3707
# [800]	train's l1: 10.1684	valid's l1: 10.3268
# [1200]	train's l1: 10.1573	valid's l1: 10.3184
# [1600]	train's l1: 10.0044	valid's l1: 10.2657
# Early stopping, best iteration is:
# [1524]	train's l1: 10.0105	valid's l1: 10.2644
# Fold 1 started at Tue Apr  2 19:15:36 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2361	valid's l1: 10.8774
# [800]	train's l1: 10.1606	valid's l1: 10.8258
# [1200]	train's l1: 10.0623	valid's l1: 10.7841
# [1600]	train's l1: 10.0503	valid's l1: 10.7777
# Early stopping, best iteration is:
# [1420]	train's l1: 10.0526	valid's l1: 10.7775
# Fold 2 started at Tue Apr  2 19:18:21 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2245	valid's l1: 10.694
# [800]	train's l1: 10.1855	valid's l1: 10.6742
# [1200]	train's l1: 10.1809	valid's l1: 10.6727
# Early stopping, best iteration is:
# [1238]	train's l1: 10.1809	valid's l1: 10.6727
# Fold 3 started at Tue Apr  2 19:21:13 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2676	valid's l1: 10.9684
# [800]	train's l1: 10.2298	valid's l1: 10.9383
# [1200]	train's l1: 10.1697	valid's l1: 10.9025
# [1600]	train's l1: 10.098	valid's l1: 10.8467
# [2000]	train's l1: 10.0722	valid's l1: 10.8268
# [2400]	train's l1: 10.0653	valid's l1: 10.8234
# [2800]	train's l1: 10.048	valid's l1: 10.8111
# [3200]	train's l1: 9.88109	valid's l1: 10.743
# [3600]	train's l1: 9.76513	valid's l1: 10.682
# [4000]	train's l1: 9.69308	valid's l1: 10.6524
# [4400]	train's l1: 9.01003	valid's l1: 10.55
# [4800]	train's l1: 8.37738	valid's l1: 10.4775
# [5200]	train's l1: 7.95837	valid's l1: 10.4624
# [5600]	train's l1: 7.75839	valid's l1: 10.4506
# Early stopping, best iteration is:
# [5434]	train's l1: 7.80701	valid's l1: 10.4485
# Fold 4 started at Tue Apr  2 19:32:01 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2209	valid's l1: 11.0517
# Early stopping, best iteration is:
# [462]	train's l1: 10.2049	valid's l1: 11.0458
# Fold 5 started at Tue Apr  2 19:33:12 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2214	valid's l1: 10.7503
# [800]	train's l1: 10.0503	valid's l1: 10.6588
# [1200]	train's l1: 10.0387	valid's l1: 10.6532
# [1600]	train's l1: 9.96588	valid's l1: 10.6193
# [2000]	train's l1: 9.85382	valid's l1: 10.5601
# [2400]	train's l1: 9.70412	valid's l1: 10.5183
# [2800]	train's l1: 9.5751	valid's l1: 10.4886
# [3200]	train's l1: 9.50271	valid's l1: 10.4587
# [3600]	train's l1: 9.48519	valid's l1: 10.4516
# [4000]	train's l1: 9.1211	valid's l1: 10.3854
# [4400]	train's l1: 9.07006	valid's l1: 10.3776
# [4800]	train's l1: 8.94778	valid's l1: 10.3612
# [5200]	train's l1: 8.8864	valid's l1: 10.3519
# [5600]	train's l1: 8.68327	valid's l1: 10.3294
# Early stopping, best iteration is:
# [5557]	train's l1: 8.68429	valid's l1: 10.3292
# Fold 6 started at Tue Apr  2 19:41:19 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2046	valid's l1: 10.9647
# [800]	train's l1: 10.0855	valid's l1: 10.896
# [1200]	train's l1: 10.016	valid's l1: 10.8672
# [1600]	train's l1: 9.92437	valid's l1: 10.8302
# [2000]	train's l1: 9.91596	valid's l1: 10.8283
# [2400]	train's l1: 9.85052	valid's l1: 10.7975
# [2800]	train's l1: 9.7831	valid's l1: 10.7659
# [3200]	train's l1: 9.6074	valid's l1: 10.7092
# [3600]	train's l1: 9.56512	valid's l1: 10.7017
# [4000]	train's l1: 9.50439	valid's l1: 10.6911
# [4400]	train's l1: 9.47845	valid's l1: 10.6851
# Early stopping, best iteration is:
# [4516]	train's l1: 9.45689	valid's l1: 10.679
# Fold 7 started at Tue Apr  2 19:47:44 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2269	valid's l1: 10.5681
# [800]	train's l1: 10.1394	valid's l1: 10.5273
# [1200]	train's l1: 10.0861	valid's l1: 10.5015
# [1600]	train's l1: 9.9338	valid's l1: 10.4415
# [2000]	train's l1: 9.89299	valid's l1: 10.435
# [2400]	train's l1: 9.84172	valid's l1: 10.4269
# [2800]	train's l1: 9.80085	valid's l1: 10.413
# [3200]	train's l1: 9.77341	valid's l1: 10.404
# [3600]	train's l1: 9.74746	valid's l1: 10.3921
# [4000]	train's l1: 9.74602	valid's l1: 10.3916
# Early stopping, best iteration is:
# [4041]	train's l1: 9.74602	valid's l1: 10.3916
# Fold 8 started at Tue Apr  2 19:53:34 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.2373	valid's l1: 10.719
# [800]	train's l1: 10.1785	valid's l1: 10.6921
# [1200]	train's l1: 10.1229	valid's l1: 10.6727
# [1600]	train's l1: 10.0942	valid's l1: 10.6587
# [2000]	train's l1: 10.0155	valid's l1: 10.6359
# [2400]	train's l1: 9.97357	valid's l1: 10.6226
# [2800]	train's l1: 9.83399	valid's l1: 10.5725
# [3200]	train's l1: 9.64475	valid's l1: 10.5387
# [3600]	train's l1: 9.52721	valid's l1: 10.5209
# Early stopping, best iteration is:
# [3657]	train's l1: 9.5	valid's l1: 10.5199
# Fold 9 started at Tue Apr  2 19:59:07 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 10.1878	valid's l1: 10.5848
# [800]	train's l1: 10.0051	valid's l1: 10.499
# [1200]	train's l1: 9.83822	valid's l1: 10.4338
# [1600]	train's l1: 9.74758	valid's l1: 10.3916
# [2000]	train's l1: 9.71444	valid's l1: 10.3792
# [2400]	train's l1: 9.70775	valid's l1: 10.378
# Early stopping, best iteration is:
# [2314]	train's l1: 9.70808	valid's l1: 10.378
# CV mean score: 10.5507, std: 0.2292.

# %%
folds = KFold(n_splits=10, shuffle=True, random_state=2019)
oof_out , predictions_out , scores_out  = train_model(X_data , X_test, all_data['outNums'], params=lgb_params, folds=folds, model_type='lgb')
test['pred_outNums']= predictions_out
# Out:
# Fold 0 started at Tue Apr  2 20:02:47 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.4401	valid's l1: 11.9198
# Early stopping, best iteration is:
# [478]	train's l1: 11.3711	valid's l1: 11.8912
# Fold 1 started at Tue Apr  2 20:04:00 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.415	valid's l1: 12.439
# [800]	train's l1: 11.3214	valid's l1: 12.3897
# [1200]	train's l1: 10.8777	valid's l1: 12.2513
# [1600]	train's l1: 10.1596	valid's l1: 12.175
# Early stopping, best iteration is:
# [1645]	train's l1: 10.1002	valid's l1: 12.1685
# Fold 2 started at Tue Apr  2 20:06:56 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.4883	valid's l1: 12.0415
# [800]	train's l1: 11.0754	valid's l1: 11.8581
# [1200]	train's l1: 10.9045	valid's l1: 11.8204
# [1600]	train's l1: 10.3708	valid's l1: 11.7824
# [2000]	train's l1: 9.61307	valid's l1: 11.7552
# Early stopping, best iteration is:
# [1946]	train's l1: 9.71908	valid's l1: 11.7532
# Fold 3 started at Tue Apr  2 20:10:30 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.4265	valid's l1: 11.6409
# Early stopping, best iteration is:
# [330]	train's l1: 11.4285	valid's l1: 11.6406
# Fold 4 started at Tue Apr  2 20:11:27 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.4632	valid's l1: 12.0965
# [800]	train's l1: 11.3521	valid's l1: 12.0115
# [1200]	train's l1: 11.2608	valid's l1: 11.9645
# [1600]	train's l1: 11.2489	valid's l1: 11.9598
# [2000]	train's l1: 11.2052	valid's l1: 11.9418
# [2400]	train's l1: 11.1572	valid's l1: 11.919
# [2800]	train's l1: 11.1195	valid's l1: 11.9047
# [3200]	train's l1: 11.032	valid's l1: 11.8854
# Early stopping, best iteration is:
# [3081]	train's l1: 11.0718	valid's l1: 11.8825
# Fold 5 started at Tue Apr  2 20:16:04 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.4023	valid's l1: 12.2198
# [800]	train's l1: 11.3812	valid's l1: 12.2081
# [1200]	train's l1: 11.2658	valid's l1: 12.1437
# [1600]	train's l1: 11.1589	valid's l1: 12.0973
# [2000]	train's l1: 11.0855	valid's l1: 12.0617
# [2400]	train's l1: 11.052	valid's l1: 12.0526
# [2800]	train's l1: 10.9978	valid's l1: 12.0319
# [3200]	train's l1: 10.8717	valid's l1: 12.0025
# [3600]	train's l1: 10.8576	valid's l1: 11.9994
# [4000]	train's l1: 10.6762	valid's l1: 11.9744
# [4400]	train's l1: 10.5178	valid's l1: 11.9632
# Early stopping, best iteration is:
# [4353]	train's l1: 10.5329	valid's l1: 11.9596
# Fold 6 started at Tue Apr  2 20:22:39 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.3674	valid's l1: 11.7373
# [800]	train's l1: 11.3662	valid's l1: 11.7372
# [1200]	train's l1: 11.3425	valid's l1: 11.7326
# [1600]	train's l1: 10.9328	valid's l1: 11.6665
# [2000]	train's l1: 10.4648	valid's l1: 11.6311
# Early stopping, best iteration is:
# [2044]	train's l1: 10.3472	valid's l1: 11.6259
# Fold 7 started at Tue Apr  2 20:26:05 2019
# Training until validation scores don't improve for 200 rounds.
# [400]	train's l1: 11.4416	valid's l1: 11.5971
# [800]	train's l1: 11.4178	valid's l1: 11.5794
# [1200]	train's l1: 11.2868	valid's l1: 11.5313
# [1600]	train's l1: 11.2157	valid's l1: 11.4992

# %%
tst = test.sort_values(['stationID','hour','minute'])
sub = pd.read_csv(path + '/Metro_testB/testB_submit_2019-01-27.csv')
sub['hour']         =  sub['startTime'].apply(lambda x: int(x[11:13]))
sub['minute']       =  sub['startTime'].apply(lambda x: int(x[14:15]+'0'))
# 真值
sub['inNums']       =  tst['inNums'].values
sub['outNums']      =  tst['outNums'].values
# 预测值
sub['pred_inNums']       =  tst['pred_inNums'].values
sub['pred_outNums']      =  tst['pred_outNums'].values
# 结果修正
sub.loc[sub.pred_inNums <0 , 'pred_inNums' ] = 0
sub.loc[sub.pred_outNums<0 , 'pred_outNums'] = 0

# %%
mean_absolute_error(np.append(sub['inNums'],sub['outNums']),np.append(sub['pred_inNums'],sub['pred_outNums']))

# %%
mean_absolute_error(sub['inNums'],sub['pred_inNums'])

# %%
mean_absolute_error(sub['outNums'],sub['pred_outNums'])

# %%
test
# Out:
#           stationID        inNums       outNums          hour        minute  \
# count  11664.000000  11664.000000  11664.000000  11664.000000  11664.000000
# mean      40.000000    107.928069    107.895833     11.500000     25.000000
# std       23.381906    156.439905    167.957510      6.922483     17.078983
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       20.000000      1.000000      1.000000      5.750000     10.000000
# 50%       40.000000     62.000000     63.000000     11.500000     25.000000
# 75%       60.000000    140.000000    136.000000     17.250000     40.000000
# max       80.000000   1457.000000   2328.000000     23.000000     50.000000
#
#         pred_inNums  pred_outNums
# count  11664.000000  11664.000000
# mean     107.182608    107.148236
# std      155.318359    167.865323
# min        0.000000      0.000000
# 25%        1.094880      1.441640
# 50%       63.103398     62.977156
# 75%      138.271098    134.340308
# max     1259.239744   2025.228305

# %%
sub1 = pd.read_csv('output/GO.csv')
sub1.loc[sub1.inNums<0 ] = 0
sub1.loc[sub1.outNums<0] = 0

# %%
sub2 = pd.read_csv('output/wh4_week67_zj6_098.csv')

# %%
print(sub1['inNums'].sum() + sub1['outNums'].sum())
print(sub2['inNums'].sum() + sub2['outNums'].sum())
# Out:
# 2130510.8646220267
# 2098095.9386765445

# %%
sub1['inNums']  = (sub['inNums'] *0.4 + sub1['inNums'] * 0.6 ) * 0.98
sub1['outNums'] = (sub['outNums']*0.4 + sub1['outNums'] * 0.6) * 0.98

# %%
mean_absolute_error(np.append(sub1['inNums'],sub1['outNums']),np.append(sub2['inNums'],sub2['outNums']))
# Out:
# 0.43119272411946863

# %%
import numpy as np
from scipy.stats import pearsonr
pearsonr(np.append(sub1['inNums'],sub1['outNums']),np.append(sub2['inNums'],sub2['outNums']))
# Out:
# (0.9999819251347666, 0.0)

# %%
sub1['init_inNums'] = sub2['inNums']

# %%
sub1['diff'] = sub1['init_inNums'].values - sub1['inNums'].values

# %%
# 模型
sub[['stationID', 'startTime', 'endTime', 'inNums', 'outNums']].to_csv('output/B_del_week7_bf7feats_model.csv', index=False)

# %%
# 验证集结果
all_data['preds_inNums']  = oof_in
all_data['preds_outNums'] = oof_out
days = all_data.day.unique()
for d in days:
    print(d,mean_absolute_error(all_data.loc[all_data.day==d,'preds_inNums'], all_data.loc[all_data.day==d,'inNums']))
# Out:
# 13 10.572294872886108
# 20 10.90452248057486

# %%
# 最终结果分析
sub1 = pd.read_csv('output/B_week7_bf1feats_model.csv')
sub2 = pd.read_csv('output/B_week6_7_bf3feats_model.csv')
sub3 = pd.read_csv('output/B_alldata_bf7feats_model.csv')
sub1['inNums']  = sub2['inNums'] *0.4 + sub3['inNums'] *0.3 + sub1['inNums']*0.3
sub1['outNums'] = sub2['outNums']*0.4 + sub3['outNums']*0.3 + sub1['outNums']*0.3
# 误差分析
fig = plt.figure(1,figsize=[20,10])
plt.ylabel('Pedestrian flow')
plt.xlabel('time')
labels = {}
labels[0] = 'sub1'
labels[1] = 'sub2'
labels[2] = 'sub3'
sub_1 = sub1[sub1.stationID==15]
sub_1 = sub_1.reset_index().reset_index()
sub_2 = sub2[sub2.stationID==15]
sub_2 = sub_2.reset_index().reset_index()
sub_3 = sub3[sub3.stationID==15]
sub_3 = sub_3.reset_index().reset_index()
nums = [r for r in range(0,sub_1.shape[0])]
plt.plot(nums,sub_1['inNums'],label = labels[0])
plt.plot(nums,sub_2['inNums'],label = labels[1])
plt.plot(nums,sub_3['inNums'],label = labels[2])
plt.legend()
plt.show()

# %%
# 融合后藏分
sub1.loc[0,'outNums'] = 11664
sub1.loc[0,'inNums']  = 11664
sub1[['stationID', 'startTime', 'endTime', 'inNums', 'outNums']].to_csv('output/67_7_all_4_3_3.csv', index=False)

# %%
# 全量和周末各取一列
sub2['inNums'] = sub3['inNums']
sub2[['stationID', 'startTime', 'endTime', 'inNums', 'outNums']].to_csv('output/B_inNums_of_alldata_outNums_of_week67.csv', index=False)

# %% [markdown]
# # EDA

# %%
def get_eda_features(df_):
    
    df = df_.copy()
    
    # base time
    df['day']     = df['time'].apply(lambda x: int(x[8:10]))
    df['hour']    = df['time'].apply(lambda x: int(x[11:13]))
    df['minute']  = df['time'].apply(lambda x: int(x[14:15]+'0'))
    
    # count,sum
    result = df.groupby(['stationID', 'day', 'hour']).status.agg(['count', 'sum']).reset_index()
        
    # in,out
    result['inNums']  = result['sum']
    result['outNums'] = result['count'] - result['sum']
    
    result.fillna(0, inplace=True)
    del result['sum'],result['count']
    
    return result

path = 'input'
test = pd.read_csv(path + '/Metro_testA/testA_submit_2019-01-29.csv')
test_28 = pd.read_csv(path + '/Metro_testA/testA_record_2019-01-28.csv')
data = get_eda_features(test_28)

# %%
data = data[:0]
data_list = os.listdir(path+'/Metro_train/')
for i in range(0, len(data_list)):
    if data_list[i].split('.')[-1] == 'csv':
        df = pd.read_csv(path+'/Metro_train/' + data_list[i])
        df = get_eda_features(df)
        data = pd.concat([data, df], axis=0, ignore_index=True)
    else:
        continue
df = get_eda_features(test_28)
data = pd.concat([data, df], axis=0, ignore_index=True)

# %%
data[:10]
# Out:
#    stationID  day  hour  inNums  outNums
# 0          0    1     5       8        1
# 1          0    1     6     209      123
# 2          0    1     7     623      159
# 3          0    1     8     818      271
# 4          0    1     9    1035      425
# 5          0    1    10    1152      562
# 6          0    1    11    1037      544
# 7          0    1    12    1166      704
# 8          0    1    13    1072      806
# 9          0    1    14    1198      958

# %%
### 相同时刻的对比
test['day']     = test['startTime'].apply(lambda x: int(x[8:10]))
test['hour']    = test['startTime'].apply(lambda x: int(x[11:13]))
test['minute']  = test['startTime'].apply(lambda x: int(x[14:15]+'0'))
for d in [2,3,4,7,8,9,10,11,14,15,16,17,18,21,22,23,24,25,28]:
    tmp = data.loc[data.day==d,['stationID','hour','minute','inNums','outNums']]
    tmp.columns = ['stationID','hour','minute','inNums'+str(d),'outNums'+str(d)]
    test = test.merge(tmp, on=['stationID','hour','minute'], how='left')
test.fillna(0, inplace=True)

# %%
### 相同时刻的对比
temp = data[(data.stationID==16)]
temp = temp.reset_index().reset_index()
fig = plt.figure(1,figsize=[20,10])
plt.ylabel('Pedestrian flow')
plt.xlabel('time')
labels = {}
for d in [21,22,23,24,25]:
    labels[d] = 'inNums'+str(d)
    tmp = temp[temp.day==d]
    nums = [r for r in range(0,tmp.shape[0])]
    plt.plot(nums,tmp['inNums'],label = labels[d])
plt.legend()
plt.show()

# %%
### 相同时刻的对比
temp = data[(data.stationID==16)]
temp = temp.reset_index().reset_index()
fig = plt.figure(1,figsize=[20,10])
plt.ylabel('Pedestrian flow')
plt.xlabel('time')
labels = {}
for d in [14,15,16,17,18]:
    labels[d] = 'inNums'+str(d)
    tmp = temp[temp.day==d]
    nums = [r for r in range(0,tmp.shape[0])]
    plt.plot(nums,tmp['inNums'],label = labels[d])
plt.legend()
plt.show()

# %%
### 相同时刻的对比
temp = data[(data.stationID==16)&(data.hour==8)&(data.minute==10)]
tempplt = temp[:0]
tmp = pd.DataFrame() 
for d in [2,3,4,7,8,9,10,11,14,15,16,17,18,21,22,23,24,25,28]:
    tmp = temp[temp.day==d]
    tempplt = pd.concat([tempplt, tmp], axis=0, ignore_index=True)
tempplt = tempplt.reset_index().reset_index()
fig = plt.figure(1,figsize=[20,10])
plt.ylabel('Pedestrian flow')
plt.xlabel('time')

nums = [r for r in range(0,tempplt.shape[0])]
plt.plot(nums,tempplt['inNums'],label = 'inNums')

plt.legend()
plt.show()

# %%
# 剔除周末,并修改为连续时间
data = data[(data.day!=5)&(data.day!=6)]
data = data[(data.day!=12)&(data.day!=13)]
data = data[(data.day!=19)&(data.day!=20)]
data = data[(data.day!=26)&(data.day!=27)]
data = data[data.day>1]
def fix_day(d):
    if d in [1,2,3,4]:
        return d
    elif d in [7,8,9,10,11]:
        return d - 2
    elif d in [14,15,16,17,18]:
        return d - 4
    elif d in [21,22,23,24,25]:
        return d - 6
    elif d in [28]:
        return d - 8
data['day'] = data['day'].apply(fix_day)

# %%
for t in range(5,24):
    fig = plt.figure(1,figsize=[20,10])
    plt.ylabel('Pedestrian flow')
    plt.xlabel('time')
    plt.title(str(t)+'h')
    labels = {}

    for i in [0,10,20,30,40,50]:
        labels[i] = 'inNums'+str(i)
        tmp = data[(data.stationID==1)&(data.hour==t)&(data.minute==i)]
        tmp = tmp.reset_index().reset_index()
        nums = [r for r in range(1,tmp.shape[0]+1)]
        plt.plot(nums,tmp['inNums'],label = labels[i])

    plt.legend()
    plt.show()

# %%
fig = plt.figure(1,figsize=[20,10])
plt.ylabel('Pedestrian flow')
plt.xlabel('time')
plt.title(str(t)+'h')
labels = {}

for i in [0,10,20,30,40,50]:
    labels[i] = 'outNums'+str(i)
    tmp = data[(data.stationID==1)&(data.hour==7)&(data.minute==i)]
    tmp = tmp.reset_index().reset_index()
    nums = [r for r in range(0,tmp.shape[0])]
    plt.plot(nums,tmp['outNums'],label = labels[i])

    plt.legend()
    plt.show()
